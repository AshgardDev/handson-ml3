# %% [markdown]
# ## 线性回归

# %%
import torch
import torch.nn as nn


class LinearNN(nn.Module):
    def __init__(self, in_features, out_features):
        super().__init__()
        self.linear = nn.Linear(in_features, out_features)

    def forward(self, x):
        return self.linear(x)

# %%
X = torch.rand(100, 2)
weight = torch.tensor([2.0, 3.0])
bias = 4
y = X @ weight + bias + torch.randn(100)*0.01
X[:10], y[:10]
# Out:
# (tensor([[0.3205, 0.5930],
#          [0.1359, 0.4212],
#          [0.0290, 0.5357],
#          [0.9512, 0.2693],
#          [0.7310, 0.5179],
#          [0.5992, 0.7047],
#          [0.7197, 0.8714],
#          [0.9044, 0.3224],
#          [0.4034, 0.9349],
#          [0.0260, 0.7980]]),
#  tensor([6.4147, 5.5313, 5.6705, 6.7208, 7.0098, 7.3037, 8.0442, 6.7397, 7.6122,
#          6.4485]))

# %%
model = LinearNN(2, 1)

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.05)

for epoch in range(1000):
    model.train()
    y_pred = model(X).squeeze()
    loss = criterion(y_pred, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if epoch % 5 == 0:
        print(f"Epoch [{epoch:03d}/100]  Loss: {loss.item():.4f}")

model.linear.weight, model.linear.bias
# Out:
# Epoch [000/100]  Loss: 39.7502
# Epoch [005/100]  Loss: 33.5919
# Epoch [010/100]  Loss: 28.0029
# Epoch [015/100]  Loss: 23.0109
# Epoch [020/100]  Loss: 18.6273
# Epoch [025/100]  Loss: 14.8457
# Epoch [030/100]  Loss: 11.6429
# Epoch [035/100]  Loss: 8.9817
# Epoch [040/100]  Loss: 6.8136
# Epoch [045/100]  Loss: 5.0833
# Epoch [050/100]  Loss: 3.7315
# Epoch [055/100]  Loss: 2.6987
# Epoch [060/100]  Loss: 1.9280
# Epoch [065/100]  Loss: 1.3668
# Epoch [070/100]  Loss: 0.9686
# Epoch [075/100]  Loss: 0.6936
# Epoch [080/100]  Loss: 0.5091
# Epoch [085/100]  Loss: 0.3889
# Epoch [090/100]  Loss: 0.3128
# Epoch [095/100]  Loss: 0.2661
# Epoch [100/100]  Loss: 0.2380
# Epoch [105/100]  Loss: 0.2213
# Epoch [110/100]  Loss: 0.2111
# Epoch [115/100]  Loss: 0.2045
# Epoch [120/100]  Loss: 0.1997
# Epoch [125/100]  Loss: 0.1956
# Epoch [130/100]  Loss: 0.1919
# Epoch [135/100]  Loss: 0.1882
# Epoch [140/100]  Loss: 0.1846
# Epoch [145/100]  Loss: 0.1809
# Epoch [150/100]  Loss: 0.1772
# Epoch [155/100]  Loss: 0.1735
# Epoch [160/100]  Loss: 0.1699
# Epoch [165/100]  Loss: 0.1663
# Epoch [170/100]  Loss: 0.1627
# Epoch [175/100]  Loss: 0.1592
# Epoch [180/100]  Loss: 0.1557
# Epoch [185/100]  Loss: 0.1523
# Epoch [190/100]  Loss: 0.1489
# Epoch [195/100]  Loss: 0.1455
# Epoch [200/100]  Loss: 0.1422
# Epoch [205/100]  Loss: 0.1390
# Epoch [210/100]  Loss: 0.1358
# Epoch [215/100]  Loss: 0.1326
# Epoch [220/100]  Loss: 0.1295
# Epoch [225/100]  Loss: 0.1264
# Epoch [230/100]  Loss: 0.1234
# Epoch [235/100]  Loss: 0.1205
# Epoch [240/100]  Loss: 0.1175
# Epoch [245/100]  Loss: 0.1147
# Epoch [250/100]  Loss: 0.1119
# Epoch [255/100]  Loss: 0.1091
# Epoch [260/100]  Loss: 0.1064
# Epoch [265/100]  Loss: 0.1038
# Epoch [270/100]  Loss: 0.1012
# Epoch [275/100]  Loss: 0.0986
# Epoch [280/100]  Loss: 0.0961
# Epoch [285/100]  Loss: 0.0937
# Epoch [290/100]  Loss: 0.0913
# Epoch [295/100]  Loss: 0.0889
# Epoch [300/100]  Loss: 0.0866
# Epoch [305/100]  Loss: 0.0844
# Epoch [310/100]  Loss: 0.0822
# Epoch [315/100]  Loss: 0.0800
# Epoch [320/100]  Loss: 0.0779
# Epoch [325/100]  Loss: 0.0759
# Epoch [330/100]  Loss: 0.0738
# Epoch [335/100]  Loss: 0.0719
# Epoch [340/100]  Loss: 0.0700
# Epoch [345/100]  Loss: 0.0681
# Epoch [350/100]  Loss: 0.0662
# Epoch [355/100]  Loss: 0.0645
# Epoch [360/100]  Loss: 0.0627
# Epoch [365/100]  Loss: 0.0610
# Epoch [370/100]  Loss: 0.0593
# Epoch [375/100]  Loss: 0.0577
# Epoch [380/100]  Loss: 0.0561
# Epoch [385/100]  Loss: 0.0545
# Epoch [390/100]  Loss: 0.0530
# Epoch [395/100]  Loss: 0.0516
# Epoch [400/100]  Loss: 0.0501
# Epoch [405/100]  Loss: 0.0487
# Epoch [410/100]  Loss: 0.0473
# Epoch [415/100]  Loss: 0.0460
# Epoch [420/100]  Loss: 0.0447
# Epoch [425/100]  Loss: 0.0434
# Epoch [430/100]  Loss: 0.0422
# Epoch [435/100]  Loss: 0.0410
# Epoch [440/100]  Loss: 0.0398
# Epoch [445/100]  Loss: 0.0386
# Epoch [450/100]  Loss: 0.0375
# Epoch [455/100]  Loss: 0.0364
# Epoch [460/100]  Loss: 0.0353
# Epoch [465/100]  Loss: 0.0343
# Epoch [470/100]  Loss: 0.0333
# Epoch [475/100]  Loss: 0.0323
# Epoch [480/100]  Loss: 0.0314
# Epoch [485/100]  Loss: 0.0304
# Epoch [490/100]  Loss: 0.0295
# Epoch [495/100]  Loss: 0.0286
# Epoch [500/100]  Loss: 0.0278
# Epoch [505/100]  Loss: 0.0269
# Epoch [510/100]  Loss: 0.0261
# Epoch [515/100]  Loss: 0.0253
# Epoch [520/100]  Loss: 0.0245
# Epoch [525/100]  Loss: 0.0238
# Epoch [530/100]  Loss: 0.0230
# Epoch [535/100]  Loss: 0.0223
# Epoch [540/100]  Loss: 0.0216
# Epoch [545/100]  Loss: 0.0210
# Epoch [550/100]  Loss: 0.0203
# Epoch [555/100]  Loss: 0.0197
# Epoch [560/100]  Loss: 0.0190
# Epoch [565/100]  Loss: 0.0184
# Epoch [570/100]  Loss: 0.0178
# Epoch [575/100]  Loss: 0.0173
# Epoch [580/100]  Loss: 0.0167
# Epoch [585/100]  Loss: 0.0162
# Epoch [590/100]  Loss: 0.0156
# Epoch [595/100]  Loss: 0.0151
# Epoch [600/100]  Loss: 0.0146
# Epoch [605/100]  Loss: 0.0142
# Epoch [610/100]  Loss: 0.0137
# Epoch [615/100]  Loss: 0.0132
# Epoch [620/100]  Loss: 0.0128
# Epoch [625/100]  Loss: 0.0124
# Epoch [630/100]  Loss: 0.0120
# Epoch [635/100]  Loss: 0.0116
# Epoch [640/100]  Loss: 0.0112
# Epoch [645/100]  Loss: 0.0108
# Epoch [650/100]  Loss: 0.0104
# Epoch [655/100]  Loss: 0.0101
# Epoch [660/100]  Loss: 0.0097
# Epoch [665/100]  Loss: 0.0094
# Epoch [670/100]  Loss: 0.0090
# Epoch [675/100]  Loss: 0.0087
# Epoch [680/100]  Loss: 0.0084
# Epoch [685/100]  Loss: 0.0081
# Epoch [690/100]  Loss: 0.0078
# Epoch [695/100]  Loss: 0.0076
# Epoch [700/100]  Loss: 0.0073
# Epoch [705/100]  Loss: 0.0070
# Epoch [710/100]  Loss: 0.0068
# Epoch [715/100]  Loss: 0.0065
# Epoch [720/100]  Loss: 0.0063
# Epoch [725/100]  Loss: 0.0061
# Epoch [730/100]  Loss: 0.0058
# Epoch [735/100]  Loss: 0.0056
# Epoch [740/100]  Loss: 0.0054
# Epoch [745/100]  Loss: 0.0052
# Epoch [750/100]  Loss: 0.0050
# Epoch [755/100]  Loss: 0.0048
# Epoch [760/100]  Loss: 0.0047
# Epoch [765/100]  Loss: 0.0045
# Epoch [770/100]  Loss: 0.0043
# Epoch [775/100]  Loss: 0.0042
# Epoch [780/100]  Loss: 0.0040
# Epoch [785/100]  Loss: 0.0038
# Epoch [790/100]  Loss: 0.0037
# Epoch [795/100]  Loss: 0.0036
# Epoch [800/100]  Loss: 0.0034
# Epoch [805/100]  Loss: 0.0033
# Epoch [810/100]  Loss: 0.0032
# Epoch [815/100]  Loss: 0.0030
# Epoch [820/100]  Loss: 0.0029
# Epoch [825/100]  Loss: 0.0028
# Epoch [830/100]  Loss: 0.0027
# Epoch [835/100]  Loss: 0.0026
# Epoch [840/100]  Loss: 0.0025
# Epoch [845/100]  Loss: 0.0024
# Epoch [850/100]  Loss: 0.0023
# Epoch [855/100]  Loss: 0.0022
# Epoch [860/100]  Loss: 0.0021
# Epoch [865/100]  Loss: 0.0020
# Epoch [870/100]  Loss: 0.0020
# Epoch [875/100]  Loss: 0.0019
# Epoch [880/100]  Loss: 0.0018
# Epoch [885/100]  Loss: 0.0017
# Epoch [890/100]  Loss: 0.0017
# Epoch [895/100]  Loss: 0.0016
# Epoch [900/100]  Loss: 0.0015
# Epoch [905/100]  Loss: 0.0015
# Epoch [910/100]  Loss: 0.0014
# Epoch [915/100]  Loss: 0.0014
# Epoch [920/100]  Loss: 0.0013
# Epoch [925/100]  Loss: 0.0012
# Epoch [930/100]  Loss: 0.0012
# Epoch [935/100]  Loss: 0.0011
# Epoch [940/100]  Loss: 0.0011
# Epoch [945/100]  Loss: 0.0011
# Epoch [950/100]  Loss: 0.0010
# Epoch [955/100]  Loss: 0.0010
# Epoch [960/100]  Loss: 0.0009
# Epoch [965/100]  Loss: 0.0009
# Epoch [970/100]  Loss: 0.0009
# Epoch [975/100]  Loss: 0.0008
# Epoch [980/100]  Loss: 0.0008
# Epoch [985/100]  Loss: 0.0008
# Epoch [990/100]  Loss: 0.0007
# Epoch [995/100]  Loss: 0.0007
# (Parameter containing:
#  tensor([[2.0543, 3.0594]], requires_grad=True),
#  Parameter containing:
#  tensor([3.9390], requires_grad=True))

# %%
with torch.no_grad():
    y_test = model(X).squeeze()

from matplotlib import pyplot as plt
plt.figure()
# 可视化预测与实际值
plt.scatter(X[:, 0], y, color='blue', label='True values')
plt.scatter(X[:, 0], y_test, color='red', label='Predictions')
plt.legend()
plt.show()
